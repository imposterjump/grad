# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import concurrent.futures
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import torch
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Check device for PyTorch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device (PyTorch):", device)

# Check device for TensorFlow
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print("GPU is available (TensorFlow)")
else:
    print("GPU is not available (TensorFlow)")

# %%
DATASET_PATHS = {
    "Crema": "../datasets/CREMA_D",
    "Ravdess": "../datasets/RAVDESS",
    "Savee": "../datasets/SAVEE",
    "Tess": "../datasets/TESS",
}

EMOTION_MAPPINGS = {
    "Ravdess": {1: 'neutral', 2: 'calm', 3: 'happy', 4: 'sad',
                5: 'angry', 6: 'fear', 7: 'disgust', 8: 'surprise'},
    "Crema": {'SAD': 'sad', 'ANG': 'angry', 'DIS': 'disgust',
              'FEA': 'fear', 'HAP': 'happy', 'NEU': 'neutral'},
    "Tess": {'neutral': 'neutral', 'happy': 'happy', 
             'sad': 'sad', 'angry': 'angry', 
             'fear': 'fear', 'disgust': 'disgust', 'ps': 'surprise'},
    "Savee": {'a': 'angry', 'd': 'disgust', 'f': 'fear',
              'h': 'happy', 'n': 'neutral', 'sa': 'sad'}
}

# %%
def load_dataset(dataset_name):
    path = DATASET_PATHS[dataset_name]
    emotion_map = EMOTION_MAPPINGS[dataset_name]
    
    file_emotion = []
    file_path = []
    
    if dataset_name == "Ravdess":
        for actor_dir in os.listdir(path):
            actor_path = os.path.join(path, actor_dir)
            if os.path.isdir(actor_path):
                for file in os.listdir(actor_path):
                    if file.endswith('.wav'):
                        parts = file.split('-')
                        emotion_code = int(parts[2])
                        file_emotion.append(emotion_map[emotion_code])
                        file_path.append(os.path.join(actor_path, file))
    
    elif dataset_name == "Crema":
        for file in os.listdir(path):
            if file.endswith('.wav'):
                parts = file.split('_')
                emotion_code = parts[2]
                file_emotion.append(emotion_map.get(emotion_code, 'unknown'))
                file_path.append(os.path.join(path, file))
    
    elif dataset_name == "Tess":
        for emotion_dir in os.listdir(path):
            emotion_path = os.path.join(path, emotion_dir)
            if os.path.isdir(emotion_path):
                emotion = emotion_dir.split('_')[-1].lower()
                for file in os.listdir(emotion_path):
                    if file.endswith('.wav'):
                        file_emotion.append(emotion_map.get(emotion, 'unknown'))
                        file_path.append(os.path.join(emotion_path, file))
    
    elif dataset_name == "Savee":
        for file in os.listdir(path):
            if file.endswith('.wav'):
                emotion_code = file.split('_')[1][0]
                file_emotion.append(emotion_map.get(emotion_code, 'unknown'))
                file_path.append(os.path.join(path, file))
    
    return pd.DataFrame({'Emotions': file_emotion, 'Path': file_path})

# %%
def combine_datasets():
    dfs = []
    for dataset in DATASET_PATHS:
        df = load_dataset(dataset)
        dfs.append(df)
    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df[combined_df['Emotions'].isin(['sad', 'angry', 'happy', 'fear', 'neutral'])]

# %%
def extract_features(data, sr):
    result = []
    
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data))
    rms = np.mean(librosa.feature.rms(y=data))
    
    stft = np.abs(librosa.stft(data))
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sr))
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sr))
    
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sr))
    
    return np.hstack([zcr, chroma, mfcc, rms, mel])

# %%
def augment_data(data, sr):
    noise_amp = 0.035 * np.random.uniform() * np.amax(data)
    noisy = data + noise_amp * np.random.normal(size=data.shape[0])

    stretched = librosa.effects.time_stretch(data, rate=0.8)

    pitched = librosa.effects.pitch_shift(data, sr=sr, n_steps=0.7)
    
    return [noisy, stretched, pitched]

# %%
def process_audio_file(file_path):
    data, sr = librosa.load(file_path, duration=2.5, offset=0.6)
    features = [extract_features(data, sr)]
    
    for augmented in augment_data(data, sr):
        features.append(extract_features(augmented, sr))
    
    return features

# %%
def prepare_data(df):
    X = []
    Y = []
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(process_audio_file, df['Path']))
    
    for idx, features in enumerate(results):
        X.extend(features)
        Y.extend([df.iloc[idx]['Emotions']] * len(features))
    
    scaler = StandardScaler()
    X = scaler.fit_transform(np.array(X))
    
    encoder = OneHotEncoder()
    Y = encoder.fit_transform(np.array(Y).reshape(-1, 1)).toarray()
    
    return train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
def build_model(input_shape, num_classes):
    model = Sequential([
        LSTM(128, return_sequences=True, input_shape=input_shape),
        Dropout(0.5),
        LSTM(64),
        Dropout(0.3),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(0.0001),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# %%
def train_model(model, X_train, y_train, X_val, y_val, epochs=50):
    lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5, min_lr=1e-7)
    
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=64,
        callbacks=[lr_reduction]
    )
    return history

# %%
def evaluate_model(model, X_test, y_test, encoder):
    y_pred = model.predict(X_test)
    y_true = encoder.inverse_transform(y_test)
    y_pred_labels = encoder.inverse_transform(y_pred)
    
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred_labels))
    
    plt.figure(figsize=(10, 8))
    cm = confusion_matrix(y_true, y_pred_labels)
    sns.heatmap(cm, annot=True, fmt='d', 
               xticklabels=encoder.categories_[0], 
               yticklabels=encoder.categories_[0])
    plt.title('Confusion Matrix')
    plt.show()

# %%
df = combine_datasets()
X_train, X_test, y_train, y_test = prepare_data(df)

# %%
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)
input_shape = (X_train.shape[1], 1)

model = build_model(input_shape, y_train.shape[1])

history = train_model(model, X_train, y_train, X_test, y_test)

evaluate_model(model, X_test, y_test, OneHotEncoder().fit(df[['Emotions']]))

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()    
plt.show()
# Out:
# Epoch 1/50
# c:\Users\10\anaconda3\envs\conda_venv\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.2561 - loss: 1.5884 - val_accuracy: 0.2858 - val_loss: 1.5597 - learning_rate: 1.0000e-04
# Epoch 2/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2891 - loss: 1.5514 - val_accuracy: 0.2979 - val_loss: 1.5435 - learning_rate: 1.0000e-04
# Epoch 3/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3040 - loss: 1.5325 - val_accuracy: 0.3068 - val_loss: 1.5283 - learning_rate: 1.0000e-04
# Epoch 4/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3123 - loss: 1.5232 - val_accuracy: 0.3186 - val_loss: 1.5100 - learning_rate: 1.0000e-04
# Epoch 5/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3294 - loss: 1.5029 - val_accuracy: 0.3467 - val_loss: 1.4795 - learning_rate: 1.0000e-04
# Epoch 6/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3437 - loss: 1.4721 - val_accuracy: 0.3519 - val_loss: 1.4392 - learning_rate: 1.0000e-04
# Epoch 7/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3393 - loss: 1.4496 - val_accuracy: 0.3546 - val_loss: 1.4203 - learning_rate: 1.0000e-04
# Epoch 8/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3535 - loss: 1.4273 - val_accuracy: 0.3709 - val_loss: 1.4041 - learning_rate: 1.0000e-04
# Epoch 9/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3638 - loss: 1.4134 - val_accuracy: 0.3820 - val_loss: 1.3891 - learning_rate: 1.0000e-04
# Epoch 10/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3705 - loss: 1.4040 - val_accuracy: 0.3948 - val_loss: 1.3734 - learning_rate: 1.0000e-04
# Epoch 11/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3778 - loss: 1.3864 - val_accuracy: 0.3962 - val_loss: 1.3588 - learning_rate: 1.0000e-04
# Epoch 12/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3923 - loss: 1.3669 - val_accuracy: 0.4028 - val_loss: 1.3450 - learning_rate: 1.0000e-04
# Epoch 13/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4019 - loss: 1.3542 - val_accuracy: 0.4199 - val_loss: 1.3314 - learning_rate: 1.0000e-04
# Epoch 14/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4107 - loss: 1.3411 - val_accuracy: 0.4225 - val_loss: 1.3203 - learning_rate: 1.0000e-04
# Epoch 15/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4066 - loss: 1.3364 - val_accuracy: 0.4233 - val_loss: 1.3129 - learning_rate: 1.0000e-04
# Epoch 16/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4200 - loss: 1.3243 - val_accuracy: 0.4337 - val_loss: 1.3024 - learning_rate: 1.0000e-04
# Epoch 17/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4180 - loss: 1.3228 - val_accuracy: 0.4385 - val_loss: 1.2965 - learning_rate: 1.0000e-04
# Epoch 18/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4234 - loss: 1.3113 - val_accuracy: 0.4412 - val_loss: 1.2884 - learning_rate: 1.0000e-04
# Epoch 19/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4284 - loss: 1.3040 - val_accuracy: 0.4501 - val_loss: 1.2815 - learning_rate: 1.0000e-04
# Epoch 20/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4351 - loss: 1.3026 - val_accuracy: 0.4585 - val_loss: 1.2717 - learning_rate: 1.0000e-04
# Epoch 21/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4432 - loss: 1.2957 - val_accuracy: 0.4573 - val_loss: 1.2657 - learning_rate: 1.0000e-04
# Epoch 22/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4420 - loss: 1.2820 - val_accuracy: 0.4634 - val_loss: 1.2612 - learning_rate: 1.0000e-04
# Epoch 23/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4558 - loss: 1.2738 - val_accuracy: 0.4663 - val_loss: 1.2540 - learning_rate: 1.0000e-04
# Epoch 24/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4556 - loss: 1.2746 - val_accuracy: 0.4701 - val_loss: 1.2477 - learning_rate: 1.0000e-04
# Epoch 25/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4588 - loss: 1.2589 - val_accuracy: 0.4731 - val_loss: 1.2447 - learning_rate: 1.0000e-04
# Epoch 26/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4593 - loss: 1.2613 - val_accuracy: 0.4809 - val_loss: 1.2371 - learning_rate: 1.0000e-04
# Epoch 27/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4649 - loss: 1.2509 - val_accuracy: 0.4778 - val_loss: 1.2335 - learning_rate: 1.0000e-04
# Epoch 28/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4625 - loss: 1.2518 - val_accuracy: 0.4835 - val_loss: 1.2290 - learning_rate: 1.0000e-04
# Epoch 29/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4658 - loss: 1.2475 - val_accuracy: 0.4803 - val_loss: 1.2247 - learning_rate: 1.0000e-04
# Epoch 30/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4684 - loss: 1.2472 - val_accuracy: 0.4851 - val_loss: 1.2195 - learning_rate: 1.0000e-04
# Epoch 31/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4708 - loss: 1.2396 - val_accuracy: 0.4902 - val_loss: 1.2142 - learning_rate: 1.0000e-04
# Epoch 32/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4768 - loss: 1.2339 - val_accuracy: 0.4879 - val_loss: 1.2129 - learning_rate: 1.0000e-04
# Epoch 33/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4791 - loss: 1.2208 - val_accuracy: 0.4893 - val_loss: 1.2096 - learning_rate: 1.0000e-04
# Epoch 34/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4762 - loss: 1.2300 - val_accuracy: 0.4898 - val_loss: 1.2065 - learning_rate: 1.0000e-04
# Epoch 35/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4754 - loss: 1.2279 - val_accuracy: 0.4863 - val_loss: 1.2092 - learning_rate: 1.0000e-04
# Epoch 36/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4821 - loss: 1.2186 - val_accuracy: 0.4916 - val_loss: 1.2014 - learning_rate: 1.0000e-04
# Epoch 37/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4773 - loss: 1.2225 - val_accuracy: 0.4960 - val_loss: 1.1978 - learning_rate: 1.0000e-04
# Epoch 38/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4803 - loss: 1.2241 - val_accuracy: 0.4934 - val_loss: 1.1941 - learning_rate: 1.0000e-04
# Epoch 39/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4870 - loss: 1.2092 - val_accuracy: 0.4973 - val_loss: 1.1932 - learning_rate: 1.0000e-04
# Epoch 40/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4775 - loss: 1.2177 - val_accuracy: 0.4963 - val_loss: 1.1912 - learning_rate: 1.0000e-04
# Epoch 41/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4866 - loss: 1.2086 - val_accuracy: 0.4898 - val_loss: 1.1940 - learning_rate: 1.0000e-04
# Epoch 42/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4829 - loss: 1.2110 - val_accuracy: 0.4972 - val_loss: 1.1883 - learning_rate: 1.0000e-04
# Epoch 43/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4858 - loss: 1.2096 - val_accuracy: 0.4979 - val_loss: 1.1856 - learning_rate: 1.0000e-04
# Epoch 44/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4894 - loss: 1.2017 - val_accuracy: 0.4952 - val_loss: 1.1869 - learning_rate: 1.0000e-04
# Epoch 45/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4850 - loss: 1.2000 - val_accuracy: 0.4997 - val_loss: 1.1833 - learning_rate: 1.0000e-04
# Epoch 46/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4902 - loss: 1.2023 - val_accuracy: 0.4977 - val_loss: 1.1821 - learning_rate: 1.0000e-04
# Epoch 47/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4848 - loss: 1.2010 - val_accuracy: 0.4996 - val_loss: 1.1792 - learning_rate: 1.0000e-04
# Epoch 48/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4879 - loss: 1.2001 - val_accuracy: 0.4948 - val_loss: 1.1838 - learning_rate: 1.0000e-04
# Epoch 49/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4882 - loss: 1.1966 - val_accuracy: 0.5009 - val_loss: 1.1777 - learning_rate: 1.0000e-04
# Epoch 50/50
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4856 - loss: 1.2057 - val_accuracy: 0.5013 - val_loss: 1.1762 - learning_rate: 1.0000e-04
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.58      0.68      0.63      1525
#         fear       0.53      0.17      0.26      1487
#        happy       0.45      0.42      0.43      1599
#      neutral       0.44      0.55      0.49      1337
#          sad       0.52      0.69      0.59      1520
#
#     accuracy                           0.50      7468
#    macro avg       0.50      0.50      0.48      7468
# weighted avg       0.50      0.50      0.48      7468
